# %% [markdown]
# <a href="https://colab.research.google.com/github/poolaNaveen/PySpark/blob/main/Pyspark4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pratice problem
from pyspark.sql import SparkSession
from pyspark.sql import *
spark = SparkSession.builder.appName('day4').getOrCreate()
df1 = spark.read.format('csv').option('header','true').load("/content/source.csv")
df1.show()
# Out:
# +---+----+
# | id|name|
# +---+----+
# |  1|   A|
# |  2|   B|
# |  3|   C|
# |  4|   D|
# +---+----+

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import count
spark.builder.appName('day6').getOrCreate()
df1 = spark.read.format('csv').option('header','true').load("/content/products-100.csv")
df1.show()
df1.select(('Brand'),('Price'),('Stock')).show()
df1.select(("Internal ID"),('Stock'),('Name')).orderBy(df1['Stock'].desc()).show()
# Out:
# +-----+--------------------+--------------------+--------------------+-------------------+-----+--------+-----+-------------+--------------+-----------+-------------+-----------+
# |Index|                Name|         Description|               Brand|           Category|Price|Currency|Stock|          EAN|         Color|       Size| Availability|Internal ID|
# +-----+--------------------+--------------------+--------------------+-------------------+-----+--------+-----+-------------+--------------+-----------+-------------+-----------+
# |    1|Compact Printer A...|Situation organiz...|Garner, Boyle and...| Books & Stationery|  265|     USD|  774|2091465262179|   ForestGreen|      Large|    pre_order|         56|
# |    2|              Tablet|Discussion loss p...|         Mueller Inc|   Shoes & Footwear|  502|     USD|   81|5286196620740|         Black|    8x10 in|     in_stock|         29|
# ...

# %%
from pyspark.sql.functions import *
df1 = spark.read.csv('join1.csv',header = True,inferSchema = True)
#df1.show()
df2 = spark.read.csv('join2.csv',header = True,inferSchema = True)
#df2.show()
df1.join(df2,df1.txnno == df2.tno).select('custno').show()
print("======= left join=========")
df1.join(df2,df1.txnno == df2.tno, 'left').drop('tno','txndate').show()
print("======= right join=========")
df1.join(df2,df1.txnno == df2.tno,'right').drop('txnno','txndate').show()
print("=== full join")
df1.join(df2,df1.txnno == df2.tno,'full').drop('txndate').show()
# Out:
# +-------+
# | custno|
# +-------+
# |4007024|
# |4006742|
# |4002199|
# +-------+
#
# ======= left join=========
# +-----+------+-------+-------+
# |txnno|amount| custno|spendby|
# +-----+------+-------+-------+
# |    0| 40.33|4007024| credit|
# |    1|198.44|4006742| credit|
# |    2|  5.58|   NULL|   NULL|
# |    3|198.19|4002199| credit|
# |    4| 98.81|   NULL|   NULL|
# +-----+------+-------+-------+
#
# ======= right join=========
# +------+---+-------+-------+
# |amount|tno| custno|spendby|
# +------+---+-------+-------+
# | 40.33|  0|4007024| credit|
# |198.44|  1|4006742| credit|
# |198.19|  3|4002199| credit|
# |  NULL|  7|6768689|   cash|
# +------+---+-------+-------+
#
# === full join
# +-----+------+----+-------+-------+
# |txnno|amount| tno| custno|spendby|
# +-----+------+----+-------+-------+
# |    0| 40.33|   0|4007024| credit|
# |    1|198.44|   1|4006742| credit|
# |    2|  5.58|NULL|   NULL|   NULL|
# |    3|198.19|   3|4002199| credit|
# ...
